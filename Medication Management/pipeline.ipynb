# %% [markdown]
# # Getting Patients data

# %%
from pprint import pprint
import pandas as pd

# Set options to display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
from mongodb_crud import MongoCRUD
import pandas as pd

uri = "mongodb+srv://mrunalmmpatil:lgOM6y88YJ9Hzky9@projects.71mo2sy.mongodb.net/?retryWrites=true&w=majority&appName=Projects"
db_name = "Medication_Management"
client = MongoCRUD(uri, db_name)

data = client.list_all_documents(collection_name="Patients")
# pprint(data)
df_P = pd.DataFrame(data)
# Out:
# ✅ Connected to MongoDB database: 'Medication_Management'

# %%
df_P.head()
# Out:
#                         _id                                    Id   BIRTHDATE  \
# 0  67f459905a7208f08a0b11f8  bad5a231-3709-952a-cf44-f8d6a52cc214  1961-11-15
# 1  67f459905a7208f08a0b1225  2bd4d47d-5e00-3b67-cdd7-03f4b811b711  1962-07-02
# 2  67f459905a7208f08a0b122c  74ad71cb-f64d-efce-02c9-ae3bc917c4a2  1994-07-24
# 3  67f459905a7208f08a0b11f2  8d2a62f2-d630-6288-93ee-0fea3f859560  1960-06-08
# 4  67f459905a7208f08a0b1217  ba459391-501f-22f5-3446-7defd52e5fab  1962-09-02
#
#     DEATHDATE          SSN    DRIVERS    PASSPORT PREFIX        FIRST  \
# 0         NaN  999-77-4825  S99987790  X35857365X    Mr.    German382
# 1         NaN  999-10-4511  S99966856  X36607749X   Mrs.     Jeana169
# 2  2022-01-17  999-16-5935  S99989927   X6467602X    Ms.     Teresa94
# 3         NaN  999-19-2698  S99950818  X66933241X   Mrs.    Elvera717
# 4  1972-06-01  999-71-2141        NaN         NaN    NaN  Maryjane289
#
# ...

# %%
df_P.shape
# Out:
# (106, 29)

# %%
data = client.list_all_documents(collection_name="Medications")
# pprint(data)
df_M = pd.DataFrame(data)

# %%
df_M.head()
# Out:
#                         _id                 START                  STOP  \
# 0  67f459975a7208f08a0b21e3  2018-04-13T01:35:34Z  2018-04-13T07:45:34Z
# 1  67f459975a7208f08a0b21fb  2018-01-11T11:07:21Z  2018-01-25T05:07:21Z
# 2  67f459975a7208f08a0b2206  2015-07-12T03:32:10Z  2015-07-12T03:32:10Z
# 3  67f459975a7208f08a0b221c  2015-04-22T08:01:49Z  2015-05-08T08:01:49Z
# 4  67f459975a7208f08a0b222a  2017-02-10T02:35:17Z  2018-02-16T02:35:17Z
#
#                                 PATIENT                                 PAYER  \
# 0  37c177ea-4398-fb7a-29fa-70eb3d673876  df166300-5a78-3502-a46a-832842197811
# 1  c1acd7ba-dacf-36d2-6010-db8934400000  0133f751-9229-3cfd-815f-b6d4979bdd6a
# 2  3648fb36-1cd1-3641-0b1c-1f00d1e7e7de  b046940f-1664-3047-bca7-dfa76be352a4
# 3  50ca7edb-0dee-35e6-5d8f-66fbcb0b37c1  a735bf55-83e9-331a-899d-a82a60b9f60c
# 4  50ca7edb-0dee-35e6-5d8f-66fbcb0b37c1  a735bf55-83e9-331a-899d-a82a60b9f60c
#
#                               ENCOUNTER     CODE  \
# ...

# %%
data = client.list_all_documents(collection_name="Allergies")
# pprint(data)
df_A = pd.DataFrame(data)

# %%
df_A.head()
# Out:
#                         _id       START  STOP  \
# 0  67f459915a7208f08a0b1244  2014-07-26   NaN
# 1  67f459915a7208f08a0b125b  1962-11-22   NaN
# 2  67f459915a7208f08a0b1266  2010-09-11   NaN
# 3  67f459915a7208f08a0b126a  2010-09-11   NaN
# 4  67f459915a7208f08a0b128c  1998-05-10   NaN
#
#                                 PATIENT                             ENCOUNTER  \
# 0  4569671e-ed39-055f-8e78-422b96c9896b  f5242c34-8841-269a-50c5-c6f623575955
# 1  bad5a231-3709-952a-cf44-f8d6a52cc214  42e5b5d3-19da-2046-20ab-ef12d3c108de
# 2  24a8f8bc-f502-5f0e-0dd7-27d64a15ed9e  20c80897-6802-5fb8-9bd0-5a37a1e3c0cd
# 3  24a8f8bc-f502-5f0e-0dd7-27d64a15ed9e  20c80897-6802-5fb8-9bd0-5a37a1e3c0cd
# 4  c1ce8dfc-3c0d-de97-ce0e-5dc0460da340  e949a49a-3f23-30c9-2942-74cf9c2475e4
#
#         CODE     SYSTEM                DESCRIPTION     TYPE     CATEGORY  \
# 0   84489001  SNOMED-CT            Mold (organism)  allergy  environment
# ...

# %%
data = client.list_all_documents(collection_name="Conditions")
# pprint(data)
df_C = pd.DataFrame(data)

# %%
df_C.head()
# Out:
#                         _id       START        STOP  \
# 0  67f459925a7208f08a0b12a3  2012-04-01  2016-04-10
# 1  67f459925a7208f08a0b12a8  2015-09-28  2015-10-31
# 2  67f459925a7208f08a0b12b9  2019-04-14         NaN
# 3  67f459925a7208f08a0b12c2  2022-04-17         NaN
# 4  67f459925a7208f08a0b12f7  2020-04-04  2020-04-04
#
#                                 PATIENT                             ENCOUNTER  \
# 0  30a6452c-4297-a1ac-977a-6a23237c7b46  294d0dab-907e-8fce-7a47-0c0d322a5734
# 1  30a6452c-4297-a1ac-977a-6a23237c7b46  953c5138-ce17-4084-3432-1ac23f184528
# 2  30a6452c-4297-a1ac-977a-6a23237c7b46  0aa3ec19-bcbd-3fb7-afc7-cf398aa417ab
# 3  30a6452c-4297-a1ac-977a-6a23237c7b46  a642e371-e468-758b-c288-3d05114236e9
# 4  0fef2411-21f0-a269-82fb-c42b55471405  a879ac7a-6c8e-14a8-0d53-603cf84874c8
#
#                    SYSTEM       CODE                        DESCRIPTION
# 0  http://snomed.info/sct   73595000                   Stress (finding)
# ...

# %%
df_P.isnull().sum()
# Out:
# _id                      0
# Id                       0
# BIRTHDATE                0
# DEATHDATE              100
# SSN                      0
# DRIVERS                 22
# PASSPORT                31
# PREFIX                  27
# FIRST                    0
# MIDDLE                  17
# LAST                     0
# SUFFIX                 106
# MAIDEN                  78
# MARITAL                 42
# RACE                     0
# ETHNICITY                0
# GENDER                   0
# BIRTHPLACE               0
# ADDRESS                  0
# CITY                     0
# STATE                    0
# COUNTY                   0
# FIPS                    35
# ZIP                      0
# LAT                      0
# LON                      0
# HEALTHCARE_EXPENSES      0
# HEALTHCARE_COVERAGE      0
# INCOME                   0
# dtype: int64

# %%
df_P.shape
# Out:
# (106, 29)

# %%
df_A.isnull().sum()
# Out:
# _id              0
# START            0
# STOP            92
# PATIENT          0
# ENCOUNTER        0
# CODE             0
# SYSTEM           0
# DESCRIPTION      0
# TYPE             0
# CATEGORY         0
# REACTION1       48
# DESCRIPTION1    48
# SEVERITY1       48
# REACTION2       62
# DESCRIPTION2    62
# SEVERITY2       62
# dtype: int64

# %%
df_A.shape
# Out:
# (92, 16)

# %%
df_C.isnull().sum()
# Out:
# _id              0
# START            0
# STOP           891
# PATIENT          0
# ENCOUNTER        0
# SYSTEM           0
# CODE             0
# DESCRIPTION      0
# dtype: int64

# %%
df_C.shape
# Out:
# (3876, 8)

# %%
df_M.isnull().sum()
# Out:
# _id                     0
# START                   0
# STOP                  245
# PATIENT                 0
# PAYER                   0
# ENCOUNTER               0
# CODE                    0
# DESCRIPTION             0
# BASE_COST               0
# PAYER_COVERAGE          0
# DISPENSES               0
# TOTALCOST               0
# REASONCODE           1271
# REASONDESCRIPTION    1271
# dtype: int64

# %%
df_M.shape
# Out:
# (5605, 14)

# %%
df_P.head()  #column to join Id
df_M.head() # column to join PATIENT
df_A.head() # column to join PATIENT
df_C.head() # column to join PATIENT
# Out:
#                         _id       START        STOP  \
# 0  67f459925a7208f08a0b12a3  2012-04-01  2016-04-10
# 1  67f459925a7208f08a0b12a8  2015-09-28  2015-10-31
# 2  67f459925a7208f08a0b12b9  2019-04-14         NaN
# 3  67f459925a7208f08a0b12c2  2022-04-17         NaN
# 4  67f459925a7208f08a0b12f7  2020-04-04  2020-04-04
#
#                                 PATIENT                             ENCOUNTER  \
# 0  30a6452c-4297-a1ac-977a-6a23237c7b46  294d0dab-907e-8fce-7a47-0c0d322a5734
# 1  30a6452c-4297-a1ac-977a-6a23237c7b46  953c5138-ce17-4084-3432-1ac23f184528
# 2  30a6452c-4297-a1ac-977a-6a23237c7b46  0aa3ec19-bcbd-3fb7-afc7-cf398aa417ab
# 3  30a6452c-4297-a1ac-977a-6a23237c7b46  a642e371-e468-758b-c288-3d05114236e9
# 4  0fef2411-21f0-a269-82fb-c42b55471405  a879ac7a-6c8e-14a8-0d53-603cf84874c8
#
#                    SYSTEM       CODE                        DESCRIPTION
# 0  http://snomed.info/sct   73595000                   Stress (finding)
# ...

# %%
df_P.columns
# Out:
# Index(['_id', 'Id', 'BIRTHDATE', 'DEATHDATE', 'SSN', 'DRIVERS', 'PASSPORT',
#        'PREFIX', 'FIRST', 'MIDDLE', 'LAST', 'SUFFIX', 'MAIDEN', 'MARITAL',
#        'RACE', 'ETHNICITY', 'GENDER', 'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE',
#        'COUNTY', 'FIPS', 'ZIP', 'LAT', 'LON', 'HEALTHCARE_EXPENSES',
#        'HEALTHCARE_COVERAGE', 'INCOME'],
#       dtype='object')

# %%
df_P_imp = df_P.drop(['_id', 'DEATHDATE', 'SSN', 'DRIVERS', 'PASSPORT',
       'PREFIX', 'FIRST', 'MIDDLE', 'LAST', 'SUFFIX', 'MAIDEN', 'MARITAL',
       'FIPS', 'ZIP', 'LAT', 'LON'], axis=1 )

# %%
df_P_imp.head()
# Out:
#                                      Id   BIRTHDATE   RACE    ETHNICITY  \
# 0  bad5a231-3709-952a-cf44-f8d6a52cc214  1961-11-15  white  nonhispanic
# 1  2bd4d47d-5e00-3b67-cdd7-03f4b811b711  1962-07-02  white  nonhispanic
# 2  74ad71cb-f64d-efce-02c9-ae3bc917c4a2  1994-07-24  white     hispanic
# 3  8d2a62f2-d630-6288-93ee-0fea3f859560  1960-06-08  white  nonhispanic
# 4  ba459391-501f-22f5-3446-7defd52e5fab  1962-09-02  white  nonhispanic
#
#   GENDER                         BIRTHPLACE                           ADDRESS  \
# 0      M  North Pembroke  Massachusetts  US  544 Morissette Esplanade Unit 30
# 1      F   North Andover  Massachusetts  US         289 Powlowski Fort Apt 42
# 2      F  Portsmouth  Saint John Parish  DM                  242 Jerde Street
# 3      F         Danvers  Massachusetts  US                 691 Jacobson Quay
# 4      F      Winchester  Massachusetts  US                   1061 Mayer Road
#
# ...

# %%
df_A.columns
# Out:
# Index(['_id', 'START', 'STOP', 'PATIENT', 'ENCOUNTER', 'CODE', 'SYSTEM',
#        'DESCRIPTION', 'TYPE', 'CATEGORY', 'REACTION1', 'DESCRIPTION1',
#        'SEVERITY1', 'REACTION2', 'DESCRIPTION2', 'SEVERITY2'],
#       dtype='object')

# %%
df_A.head()
# Out:
#                         _id       START  STOP  \
# 0  67f459915a7208f08a0b1244  2014-07-26   NaN
# 1  67f459915a7208f08a0b125b  1962-11-22   NaN
# 2  67f459915a7208f08a0b1266  2010-09-11   NaN
# 3  67f459915a7208f08a0b126a  2010-09-11   NaN
# 4  67f459915a7208f08a0b128c  1998-05-10   NaN
#
#                                 PATIENT                             ENCOUNTER  \
# 0  4569671e-ed39-055f-8e78-422b96c9896b  f5242c34-8841-269a-50c5-c6f623575955
# 1  bad5a231-3709-952a-cf44-f8d6a52cc214  42e5b5d3-19da-2046-20ab-ef12d3c108de
# 2  24a8f8bc-f502-5f0e-0dd7-27d64a15ed9e  20c80897-6802-5fb8-9bd0-5a37a1e3c0cd
# 3  24a8f8bc-f502-5f0e-0dd7-27d64a15ed9e  20c80897-6802-5fb8-9bd0-5a37a1e3c0cd
# 4  c1ce8dfc-3c0d-de97-ce0e-5dc0460da340  e949a49a-3f23-30c9-2942-74cf9c2475e4
#
#         CODE     SYSTEM                DESCRIPTION     TYPE     CATEGORY  \
# 0   84489001  SNOMED-CT            Mold (organism)  allergy  environment
# ...

# %%
df_A_imp = df_A.drop(['_id', 'STOP', 'ENCOUNTER', 'SYSTEM', 'TYPE'], axis=1)

# %%
for col in df_A.columns:
    print(df_A[col].value_counts())
    print("----------------------------")
# Out:
# _id
# 67f459915a7208f08a0b1244    1
# 67f459915a7208f08a0b125c    1
# 67f459915a7208f08a0b1287    1
# 67f459915a7208f08a0b1275    1
# 67f459915a7208f08a0b1260    1
# 67f459915a7208f08a0b1257    1
# 67f459915a7208f08a0b1254    1
# 67f459915a7208f08a0b124e    1
# 67f459915a7208f08a0b1296    1
# 67f459915a7208f08a0b128e    1
# 67f459915a7208f08a0b1286    1
# 67f459915a7208f08a0b1298    1
# 67f459915a7208f08a0b125b    1
# 67f459915a7208f08a0b1291    1
# 67f459915a7208f08a0b128d    1
# 67f459915a7208f08a0b127c    1
# 67f459915a7208f08a0b1249    1
# 67f459915a7208f08a0b1245    1
# 67f459915a7208f08a0b1297    1
# 67f459915a7208f08a0b1285    1
# 67f459915a7208f08a0b1277    1
# 67f459915a7208f08a0b1274    1
# 67f459915a7208f08a0b124d    1
# 67f459915a7208f08a0b1252    1
# 67f459915a7208f08a0b1259    1
# 67f459915a7208f08a0b125f    1
# 67f459915a7208f08a0b1281    1
# 67f459915a7208f08a0b1278    1
# 67f459915a7208f08a0b1276    1
# 67f459915a7208f08a0b126f    1
# 67f459915a7208f08a0b1263    1
# ...

# %%
for col in df_C.columns:
    print(df_C[col].value_counts())
    print("----------------------------")
# Out:
# _id
# 67f459925a7208f08a0b12a3    1
# 67f459925a7208f08a0b1d55    1
# 67f459925a7208f08a0b1d83    1
# 67f459925a7208f08a0b1d90    1
# 67f459925a7208f08a0b1d9d    1
# 67f459925a7208f08a0b1d9f    1
# 67f459925a7208f08a0b1da2    1
# 67f459925a7208f08a0b1da7    1
# 67f459925a7208f08a0b1dac    1
# 67f459925a7208f08a0b1dad    1
# 67f459925a7208f08a0b1db8    1
# 67f459925a7208f08a0b1dd4    1
# 67f459925a7208f08a0b1e0c    1
# 67f459925a7208f08a0b1e1b    1
# 67f459925a7208f08a0b1e1d    1
# 67f459925a7208f08a0b1e49    1
# 67f459925a7208f08a0b1c81    1
# 67f459925a7208f08a0b1c92    1
# 67f459925a7208f08a0b1caf    1
# 67f459925a7208f08a0b1cc2    1
# 67f459925a7208f08a0b1cd2    1
# 67f459925a7208f08a0b1cdf    1
# 67f459925a7208f08a0b1ce0    1
# 67f459925a7208f08a0b1ce5    1
# 67f459925a7208f08a0b1d0c    1
# 67f459925a7208f08a0b1d12    1
# 67f459925a7208f08a0b1d1b    1
# 67f459925a7208f08a0b1d3c    1
# 67f459925a7208f08a0b1d43    1
# 67f459925a7208f08a0b1d73    1
# 67f459925a7208f08a0b1d64    1
# ...

# %%
df_C.head()
# Out:
#                         _id       START        STOP  \
# 0  67f459925a7208f08a0b12a3  2012-04-01  2016-04-10
# 1  67f459925a7208f08a0b12a8  2015-09-28  2015-10-31
# 2  67f459925a7208f08a0b12b9  2019-04-14         NaN
# 3  67f459925a7208f08a0b12c2  2022-04-17         NaN
# 4  67f459925a7208f08a0b12f7  2020-04-04  2020-04-04
#
#                                 PATIENT                             ENCOUNTER  \
# 0  30a6452c-4297-a1ac-977a-6a23237c7b46  294d0dab-907e-8fce-7a47-0c0d322a5734
# 1  30a6452c-4297-a1ac-977a-6a23237c7b46  953c5138-ce17-4084-3432-1ac23f184528
# 2  30a6452c-4297-a1ac-977a-6a23237c7b46  0aa3ec19-bcbd-3fb7-afc7-cf398aa417ab
# 3  30a6452c-4297-a1ac-977a-6a23237c7b46  a642e371-e468-758b-c288-3d05114236e9
# 4  0fef2411-21f0-a269-82fb-c42b55471405  a879ac7a-6c8e-14a8-0d53-603cf84874c8
#
#                    SYSTEM       CODE                        DESCRIPTION
# 0  http://snomed.info/sct   73595000                   Stress (finding)
# ...

# %%
df_C.columns
# Out:
# Index(['_id', 'START', 'STOP', 'PATIENT', 'ENCOUNTER', 'SYSTEM', 'CODE',
#        'DESCRIPTION'],
#       dtype='object')

# %%
df_C.STOP.isnull().sum()
# Out:
# np.int64(891)

# %%
df_C_imp = df_C.drop(['_id', 'STOP', 'ENCOUNTER', 'SYSTEM' ], axis=1)

# %%
df_M.head()
# Out:
#                         _id                 START                  STOP  \
# 0  67f459975a7208f08a0b21e3  2018-04-13T01:35:34Z  2018-04-13T07:45:34Z
# 1  67f459975a7208f08a0b21fb  2018-01-11T11:07:21Z  2018-01-25T05:07:21Z
# 2  67f459975a7208f08a0b2206  2015-07-12T03:32:10Z  2015-07-12T03:32:10Z
# 3  67f459975a7208f08a0b221c  2015-04-22T08:01:49Z  2015-05-08T08:01:49Z
# 4  67f459975a7208f08a0b222a  2017-02-10T02:35:17Z  2018-02-16T02:35:17Z
#
#                                 PATIENT                                 PAYER  \
# 0  37c177ea-4398-fb7a-29fa-70eb3d673876  df166300-5a78-3502-a46a-832842197811
# 1  c1acd7ba-dacf-36d2-6010-db8934400000  0133f751-9229-3cfd-815f-b6d4979bdd6a
# 2  3648fb36-1cd1-3641-0b1c-1f00d1e7e7de  b046940f-1664-3047-bca7-dfa76be352a4
# 3  50ca7edb-0dee-35e6-5d8f-66fbcb0b37c1  a735bf55-83e9-331a-899d-a82a60b9f60c
# 4  50ca7edb-0dee-35e6-5d8f-66fbcb0b37c1  a735bf55-83e9-331a-899d-a82a60b9f60c
#
#                               ENCOUNTER     CODE  \
# ...

# %%
df_M.columns
# Out:
# Index(['_id', 'START', 'STOP', 'PATIENT', 'PAYER', 'ENCOUNTER', 'CODE',
#        'DESCRIPTION', 'BASE_COST', 'PAYER_COVERAGE', 'DISPENSES', 'TOTALCOST',
#        'REASONCODE', 'REASONDESCRIPTION'],
#       dtype='object')

# %%
df_M.DISPENSES.value_counts()
# Out:
# DISPENSES
# 1      3894
# 3       942
# 4       272
# 12      217
# 2       116
# 10       19
# 6        12
# 7        12
# 9         8
# 42        6
# 8         6
# 5         6
# 146       5
# 231       4
# 236       4
# 123       4
# 69        4
# 154       4
# 292       4
# 129       4
# 286       4
# 11        4
# 370       3
# 341       3
# 183       2
# 355       2
# 125       2
# 322       2
# 553       2
# 139       2
# 60        2
# 172       2
# 447       2
# 149       2
# 280       1
# 638       1
# 14        1
# 223       1
# 631       1
# 751       1
# 730       1
# 194       1
# 13        1
# 440       1
# 106       1
# 50        1
# 33        1
# 88        1
# 171       1
# 718       1
# 496       1
# 200       1
# 485       1
# 525       1
# 97        1
# 82        1
# 452       1
# 451       1
# 801       1
# 92        1
# 694       1
# 161       1
# Name: count, dtype: int64

# %%
df_M_imp = df_M.drop(['_id', 'STOP', 'PAYER', 'ENCOUNTER'], axis = 1)

# %%
df_C_imp.PATIENT.value_counts()
# Out:
# PATIENT
# bad5a231-3709-952a-cf44-f8d6a52cc214    241
# f3884e8a-8b36-1e93-66dd-e910dfab2ef5    228
# d27273f0-f62d-7d7f-746d-4565f35cf176    178
# d1622e8b-d26b-ec81-ffcb-ec4bf2af385b    141
# 655baba7-47ed-22ac-2093-1196ebb44928    110
# 14dc5e57-1b84-3305-c042-86c9fc7e4996    106
# 6c602779-9775-f512-2724-fa4e0d0788f5     90
# cb1b46a1-9cb5-1187-ccc5-9fb7b98aa957     89
# 4f159375-4ee4-36ab-b464-6d38f6ff2dae     75
# 916b1ac8-56c8-ec1b-3b9a-721336a74912     73
# bd2a8021-2868-6dd2-c17f-bfd7c36fe247     66
# 00732e11-5e4d-37b7-01f8-929a25536862     58
# d5635f98-2461-70a1-5916-f854efa27fc0     54
# fb164202-4e38-04a0-470a-b7229db13c04     51
# 488e5395-0a2a-f2da-0389-e0e8062b009d     45
# f339a5f7-0b09-3072-2b01-7c8e8ca2c1fc     45
# bcd4d6cd-0c79-a19e-5b9e-64816e3fd72d     44
# d426334c-a982-3a31-7e0f-ca3c7fe01310     43
# 8d2a62f2-d630-6288-93ee-0fea3f859560     43
# 3ec070e8-7f78-6a8b-12d7-9ee9808012e0     42
# c1ce8dfc-3c0d-de97-ce0e-5dc0460da340     41
# ...

# %%
df_P_imp.merge(df_A_imp, left_on="Id", right_on='PATIENT', how='left').merge(df_C_imp,left_on="Id", right_on='PATIENT', how='inner').PATIENT_x.duplicated().sum()
# Out:
# np.int64(8534)

# %%
merged_df = df_P_imp.merge(df_A_imp, left_on="Id", right_on='PATIENT', how='left') \
                .merge(df_C_imp,left_on="Id", right_on='PATIENT', how='inner') \
                .merge(df_M_imp,left_on="Id", right_on='PATIENT', how='inner')

# %%
merged_df.head(), merged_df.shape
# Out:
# (                                     Id   BIRTHDATE   RACE    ETHNICITY  \
#  0  bad5a231-3709-952a-cf44-f8d6a52cc214  1961-11-15  white  nonhispanic
#  1  bad5a231-3709-952a-cf44-f8d6a52cc214  1961-11-15  white  nonhispanic
#  2  bad5a231-3709-952a-cf44-f8d6a52cc214  1961-11-15  white  nonhispanic
#  3  bad5a231-3709-952a-cf44-f8d6a52cc214  1961-11-15  white  nonhispanic
#  4  bad5a231-3709-952a-cf44-f8d6a52cc214  1961-11-15  white  nonhispanic
#
#    GENDER                         BIRTHPLACE                           ADDRESS  \
#  0      M  North Pembroke  Massachusetts  US  544 Morissette Esplanade Unit 30
#  1      M  North Pembroke  Massachusetts  US  544 Morissette Esplanade Unit 30
#  2      M  North Pembroke  Massachusetts  US  544 Morissette Esplanade Unit 30
#  3      M  North Pembroke  Massachusetts  US  544 Morissette Esplanade Unit 30
#  4      M  North Pembroke  Massachusetts  US  544 Morissette Esplanade Unit 30
#
# ...

# %%
merged_df.columns

# %%
merged_df_filtered = merged_df.drop(['PATIENT_x','PATIENT_y', 'PATIENT'], axis=1)

# %%
merged_df_filtered.columns

# %%
merged_df_final = merged_df_filtered.rename(columns={'START_x': 'START_allergy', 'CODE_x': 'CODE_allergy', "DESCRIPTION_x":"DESCRIPTION_allergy", 'CATEGORY':'CATEGORY_allergy', 'REACTION1':'REACTION1_allergy', 'DESCRIPTION1': 'DESCRIPTION1_allergy', 'SEVERITY1':'SEVERITY1_allergy', 'REACTION2':'REACTION2_allergy', 'DESCRIPTION2': 'DESCRIPTION2_allergy', 'SEVERITY2':'SEVERITY2_allergy', 'START_y': 'START_condition', 'CODE_y': 'CODE_condition', "DESCRIPTION_y":"DESCRIPTION_condition",'START':'START_medication', 'CODE':'CODE_medication', 'DESCRIPTION':'DESCRIPTION_medication', 'BASE_COST':"BASE_COST_medication", 'PAYER_COVERAGE':'PAYER_COVERAGE_medication',
       'DISPENSES':'DISPENSES_medication', 'TOTALCOST':'TOTALCOST_medication', 'REASONCODE':'REASONCODE_medication', 'REASONDESCRIPTION':'REASONDESCRIPTION_medication'})

# %%
merged_df_final.head()

# %%
merged_df_final.info()

# %% [markdown]
# # Conversions

# %%
# Convert Birthdate, START_allergy, START_condition, START_medication to datetime

# %%
merged_df_final.shape

# %%
date_cols = ['BIRTHDATE', 'START_allergy', 'START_condition', 'START_medication']
merged_df_final[date_cols] = merged_df_final[date_cols].apply(pd.to_datetime, errors='coerce')
merged_df_final.head()

# %%
# Convert Birthplace to city, state, country

# %%
# Duplicate Removal
merged_df_final = merged_df_final.drop_duplicates()

# %%
# Check nulls and see if some imp field has a lot then drop rows
merged_df_final.isnull().sum()

# %%
# lowerCase all text field

# %%
# Out-of-Pocket Cost calculation

# %%
# Flag Allergic Conflicts
