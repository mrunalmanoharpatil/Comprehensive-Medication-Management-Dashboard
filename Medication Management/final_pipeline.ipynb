# %%
from pprint import pprint
import pandas as pd

# Set options to display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
from mongodb_crud import MongoCRUD
import pandas as pd

uri = "mongodb+srv://mrunalmmpatil:lgOM6y88YJ9Hzky9@projects.71mo2sy.mongodb.net/?retryWrites=true&w=majority&appName=Projects"
db_name = "Medication_Management"
client = MongoCRUD(uri, db_name)

data = client.list_all_documents(collection_name="Patients")
# pprint(data)
df_P = pd.DataFrame(data)
# Out:
# ✅ Connected to MongoDB database: 'Medication_Management'

# %%
data = client.list_all_documents(collection_name="Medications")
# pprint(data)
df_M = pd.DataFrame(data)
data = client.list_all_documents(collection_name="Allergies")
# pprint(data)
df_A = pd.DataFrame(data)
data = client.list_all_documents(collection_name="Conditions")
# pprint(data)
df_C = pd.DataFrame(data)

# %%
df_P_imp = df_P.drop(['_id', 'DEATHDATE', 'SSN', 'DRIVERS', 'PASSPORT',
       'PREFIX', 'FIRST', 'MIDDLE', 'LAST', 'SUFFIX', 'MAIDEN', 'MARITAL',
       'FIPS', 'ZIP', 'LAT', 'LON'], axis=1 ) 


df_A_imp = df_A.drop(['_id', 'STOP', 'ENCOUNTER', 'SYSTEM', 'TYPE'], axis=1)
df_C_imp = df_C.drop(['_id', 'ENCOUNTER', 'SYSTEM' ], axis=1)

df_M_imp = df_M.drop(['_id', 'PAYER', 'ENCOUNTER'], axis = 1)

# %% [markdown]
# # Convert Dates to Datetime Format:

# %%
df_P_imp['BIRTHDATE'] = pd.to_datetime(df_P_imp['BIRTHDATE'])
df_A_imp['START'] = pd.to_datetime(df_A_imp['START'])
df_C_imp['START'] = pd.to_datetime(df_C_imp['START'])
df_M_imp['START'] = pd.to_datetime(df_M_imp['START'])
df_C_imp['STOP'] = pd.to_datetime(df_C_imp['STOP'])
df_M_imp['STOP'] = pd.to_datetime(df_M_imp['STOP'])

# %%
birthplace_split = df_P_imp['BIRTHPLACE'].str.rsplit(' ', n=2, expand=True)
df_P_imp['BIRTHPLACE_COUNTRY'] = birthplace_split[2]
df_P_imp.head()
# Out:
#                                      Id  BIRTHDATE   RACE    ETHNICITY GENDER  \
# 0  bad5a231-3709-952a-cf44-f8d6a52cc214 1961-11-15  white  nonhispanic      M
# 1  2bd4d47d-5e00-3b67-cdd7-03f4b811b711 1962-07-02  white  nonhispanic      F
# 2  74ad71cb-f64d-efce-02c9-ae3bc917c4a2 1994-07-24  white     hispanic      F
# 3  8d2a62f2-d630-6288-93ee-0fea3f859560 1960-06-08  white  nonhispanic      F
# 4  ba459391-501f-22f5-3446-7defd52e5fab 1962-09-02  white  nonhispanic      F
#
#                           BIRTHPLACE                           ADDRESS  \
# 0  North Pembroke  Massachusetts  US  544 Morissette Esplanade Unit 30
# 1   North Andover  Massachusetts  US         289 Powlowski Fort Apt 42
# 2  Portsmouth  Saint John Parish  DM                  242 Jerde Street
# 3         Danvers  Massachusetts  US                 691 Jacobson Quay
# 4      Winchester  Massachusetts  US                   1061 Mayer Road
#
# ...

# %%
df_P_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   106 non-null    object
#  1   BIRTHDATE            106 non-null    datetime64[ns]
#  2   RACE                 106 non-null    object
#  3   ETHNICITY            106 non-null    object
#  4   GENDER               106 non-null    object
#  5   BIRTHPLACE           106 non-null    object
#  6   ADDRESS              106 non-null    object
#  7   CITY                 106 non-null    object
#  8   STATE                106 non-null    object
#  9   COUNTY               106 non-null    object
#  10  HEALTHCARE_EXPENSES  106 non-null    float64
#  11  HEALTHCARE_COVERAGE  106 non-null    float64
#  12  INCOME               106 non-null    int64
#  13  BIRTHPLACE_COUNTRY   106 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(10)
# ...

# %%
df_A_imp.head()
# Out:
#        START                               PATIENT       CODE  \
# 0 2014-07-26  4569671e-ed39-055f-8e78-422b96c9896b   84489001
# 1 1962-11-22  bad5a231-3709-952a-cf44-f8d6a52cc214  264287008
# 2 2010-09-11  24a8f8bc-f502-5f0e-0dd7-27d64a15ed9e   84489001
# 3 2010-09-11  24a8f8bc-f502-5f0e-0dd7-27d64a15ed9e  782576004
# 4 1998-05-10  c1ce8dfc-3c0d-de97-ce0e-5dc0460da340  111088007
#
#                  DESCRIPTION     CATEGORY    REACTION1  \
# 0            Mold (organism)  environment          NaN
# 1  Animal dander (substance)  environment  878820003.0
# 2            Mold (organism)  environment   21626009.0
# 3    Tree pollen (substance)  environment          NaN
# 4          Latex (substance)  environment  402387002.0
#
#                             DESCRIPTION1 SEVERITY1    REACTION2  \
# 0                                    NaN       NaN          NaN
# 1         Rhinoconjunctivitis (disorder)  MODERATE          NaN
# ...

# %%
df_A_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   START         92 non-null     datetime64[ns]
#  1   PATIENT       92 non-null     object
#  2   CODE          92 non-null     int64
#  3   DESCRIPTION   92 non-null     object
#  4   CATEGORY      92 non-null     object
#  5   REACTION1     44 non-null     float64
#  6   DESCRIPTION1  44 non-null     object
#  7   SEVERITY1     44 non-null     object
#  8   REACTION2     30 non-null     float64
#  9   DESCRIPTION2  30 non-null     object
#  10  SEVERITY2     30 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7)
# memory usage: 8.0+ KB

# %%
df_C_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3876 entries, 0 to 3875
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START        3876 non-null   datetime64[ns]
#  1   STOP         2985 non-null   datetime64[ns]
#  2   PATIENT      3876 non-null   object
#  3   CODE         3876 non-null   int64
#  4   DESCRIPTION  3876 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 151.5+ KB

# %%
df_C_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3876 entries, 0 to 3875
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START        3876 non-null   datetime64[ns]
#  1   STOP         2985 non-null   datetime64[ns]
#  2   PATIENT      3876 non-null   object
#  3   CODE         3876 non-null   int64
#  4   DESCRIPTION  3876 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 151.5+ KB

# %%
df_C_imp['DESCRIPTION'] = df_C_imp['DESCRIPTION'].str.lower()
df_A_imp['DESCRIPTION'] = df_A_imp['DESCRIPTION'].str.lower()
df_A_imp['DESCRIPTION1'] = df_A_imp['DESCRIPTION1'].str.lower()
df_A_imp['DESCRIPTION2'] = df_A_imp['DESCRIPTION2'].str.lower()
df_M_imp['DESCRIPTION'] = df_M_imp['DESCRIPTION'].str.lower()
df_M_imp['REASONDESCRIPTION'] = df_M_imp['REASONDESCRIPTION'].str.lower()

# %%
today = pd.to_datetime("today")
df_P_imp['AGE'] = (today - df_P_imp['BIRTHDATE']).dt.days // 365

# %%
df_P_imp.describe()
# Out:
#                            BIRTHDATE  HEALTHCARE_EXPENSES  \
# count                            106         1.060000e+02
# mean   1984-10-06 03:23:46.415094336         2.022482e+05
# min              1914-03-03 00:00:00         5.275400e+02
# 25%              1964-10-07 18:00:00         2.980308e+04
# 50%              1984-06-11 12:00:00         9.313202e+04
# 75%              2006-05-28 06:00:00         2.431280e+05
# max              2023-03-01 00:00:00         1.157947e+06
# std                              NaN         2.631096e+05
#
#        HEALTHCARE_COVERAGE         INCOME         AGE
# count         1.060000e+02     106.000000  106.000000
# mean          2.987003e+05  106080.056604   40.018868
# min           0.000000e+00    7361.000000    2.000000
# 25%           1.313933e+04   35910.250000   18.250000
# 50%           1.878933e+05   76761.500000   40.500000
# 75%           4.393279e+05  117661.000000   60.250000
# max           1.441489e+06  816851.000000  111.000000
# ...

# %%
df_M_imp['START'] = pd.to_datetime(df_M_imp['START'])
df_M_imp['STOP'] = pd.to_datetime(df_M_imp['STOP'])
df_M_imp['DAYS_SUPPLY'] = (df_M_imp['STOP'] - df_M_imp['START']).dt.days

# %%
df_M_imp.head()
# Out:
#                       START                      STOP  \
# 0 2018-04-13 01:35:34+00:00 2018-04-13 07:45:34+00:00
# 1 2018-01-11 11:07:21+00:00 2018-01-25 05:07:21+00:00
# 2 2015-07-12 03:32:10+00:00 2015-07-12 03:32:10+00:00
# 3 2015-04-22 08:01:49+00:00 2015-05-08 08:01:49+00:00
# 4 2017-02-10 02:35:17+00:00 2018-02-16 02:35:17+00:00
#
#                                 PATIENT     CODE  \
# 0  37c177ea-4398-fb7a-29fa-70eb3d673876  1648755
# 1  c1acd7ba-dacf-36d2-6010-db8934400000   834102
# 2  3648fb36-1cd1-3641-0b1c-1f00d1e7e7de  1535362
# 3  50ca7edb-0dee-35e6-5d8f-66fbcb0b37c1   313782
# 4  50ca7edb-0dee-35e6-5d8f-66fbcb0b37c1   314076
#
#                                          DESCRIPTION  BASE_COST  \
# 0  nitrofurantoin  macrocrystals 25 mg / nitrofur...     129.94
# 1          penicillin v potassium 500 mg oral tablet      67.02
# 2              sodium fluoride 0.0272 mg/mg oral gel     129.94
# 3                   acetaminophen 325 mg oral tablet      45.86
# ...

# %%
def check_allergy_conflict(med_desc, allergies):
    return any(allergy in med_desc for allergy in allergies)

patient_allergies = df_A_imp.groupby('PATIENT')['DESCRIPTION'].apply(list).to_dict()
df_M_imp['allergy_conflict'] = df_M_imp.apply(
    lambda row: check_allergy_conflict(row['DESCRIPTION'], patient_allergies.get(row['PATIENT'], [])), axis=1
)
df_M_imp.head()
# Out:
#                       START                      STOP  \
# 0 2018-04-13 01:35:34+00:00 2018-04-13 07:45:34+00:00
# 1 2018-01-11 11:07:21+00:00 2018-01-25 05:07:21+00:00
# 2 2015-07-12 03:32:10+00:00 2015-07-12 03:32:10+00:00
# 3 2015-04-22 08:01:49+00:00 2015-05-08 08:01:49+00:00
# 4 2017-02-10 02:35:17+00:00 2018-02-16 02:35:17+00:00
#
#                                 PATIENT     CODE  \
# 0  37c177ea-4398-fb7a-29fa-70eb3d673876  1648755
# 1  c1acd7ba-dacf-36d2-6010-db8934400000   834102
# 2  3648fb36-1cd1-3641-0b1c-1f00d1e7e7de  1535362
# 3  50ca7edb-0dee-35e6-5d8f-66fbcb0b37c1   313782
# 4  50ca7edb-0dee-35e6-5d8f-66fbcb0b37c1   314076
#
#                                          DESCRIPTION  BASE_COST  \
# 0  nitrofurantoin  macrocrystals 25 mg / nitrofur...     129.94
# 1          penicillin v potassium 500 mg oral tablet      67.02
# 2              sodium fluoride 0.0272 mg/mg oral gel     129.94
# 3                   acetaminophen 325 mg oral tablet      45.86
# ...

# %%
# agg_AD = df_A_imp.groupby('PATIENT')['DESCRIPTION'].apply(lambda x: list(x.unique())).reset_index()
# agg_AD.columns = ['PATIENT', 'DESCRIPTION']

# agg_AD1 = df_A_imp.groupby('PATIENT')['DESCRIPTION1'].apply(lambda x: list(x.unique())).reset_index()
# agg_AD1.columns = ['PATIENT', 'DESCRIPTION1']

# agg_AD2 = df_A_imp.groupby('PATIENT')['DESCRIPTION2'].apply(lambda x: list(x.unique())).reset_index()
# agg_AD2.columns = ['PATIENT', 'DESCRIPTION2']


# df_A_imp['DESCRIPTION'] = agg_AD['DESCRIPTION']
# df_A_imp['DESCRIPTION1'] = agg_AD1['DESCRIPTION1']
# df_A_imp['DESCRIPTION2'] = agg_AD2['DESCRIPTION2']

# df_A_imp.head()

# %%
len(list(df_C_imp.PATIENT.unique()))
# Out:
# 106

# %%
df_A_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   START         92 non-null     datetime64[ns]
#  1   PATIENT       92 non-null     object
#  2   CODE          92 non-null     int64
#  3   DESCRIPTION   92 non-null     object
#  4   CATEGORY      92 non-null     object
#  5   REACTION1     44 non-null     float64
#  6   DESCRIPTION1  44 non-null     object
#  7   SEVERITY1     44 non-null     object
#  8   REACTION2     30 non-null     float64
#  9   DESCRIPTION2  30 non-null     object
#  10  SEVERITY2     30 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7)
# memory usage: 8.0+ KB

# %%
# Step 1: Create a copy to work safely
df_allergies_cleaned = df_A_imp.copy()

# Step 2: Aggregate
df_allergy_agg = df_allergies_cleaned.groupby('PATIENT').agg({
    'START': 'min',  # earliest allergy record
    'DESCRIPTION': lambda x: ', '.join(x.dropna().unique()),
    'DESCRIPTION1': lambda x: ', '.join(x.dropna().unique()),
    'DESCRIPTION2': lambda x: ', '.join(x.dropna().unique()),
    'SEVERITY1': lambda x: ', '.join(x.dropna().unique()),
    'SEVERITY2': lambda x: ', '.join(x.dropna().unique())
}).reset_index()

# Optional: Rename for clarity
df_allergy_agg.rename(columns={
    'START': 'ALLERGY_START_DATE',
    'DESCRIPTION': 'ALLERGIES',
    'DESCRIPTION1': 'REACTION_DESC_1',
    'DESCRIPTION2': 'REACTION_DESC_2',
    'SEVERITY1': 'SEVERITY_1',
    'SEVERITY2': 'SEVERITY_2'
}, inplace=True)

df_allergy_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PATIENT             15 non-null     object
#  1   ALLERGY_START_DATE  15 non-null     datetime64[ns]
#  2   ALLERGIES           15 non-null     object
#  3   REACTION_DESC_1     15 non-null     object
#  4   REACTION_DESC_2     15 non-null     object
#  5   SEVERITY_1          15 non-null     object
#  6   SEVERITY_2          15 non-null     object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 968.0+ bytes

# %%
df_M_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5605 entries, 0 to 5604
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   START              5605 non-null   datetime64[ns, UTC]
#  1   STOP               5360 non-null   datetime64[ns, UTC]
#  2   PATIENT            5605 non-null   object
#  3   CODE               5605 non-null   int64
#  4   DESCRIPTION        5605 non-null   object
#  5   BASE_COST          5605 non-null   float64
#  6   PAYER_COVERAGE     5605 non-null   float64
#  7   DISPENSES          5605 non-null   int64
#  8   TOTALCOST          5605 non-null   float64
#  9   REASONCODE         4334 non-null   float64
#  10  REASONDESCRIPTION  4334 non-null   object
#  11  DAYS_SUPPLY        5360 non-null   float64
#  12  allergy_conflict   5605 non-null   bool
# dtypes: bool(1), datetime64[ns, UTC](2), float64(5), int64(2), object(3)
# memory usage: 531.1+ KB

# %%
df_med_agg = df_M_imp.groupby("PATIENT").agg({
    'START': 'min',
    'STOP': 'max',
    'DESCRIPTION': lambda x: ', '.join(x.dropna().unique()),
    'TOTALCOST': 'sum',
    'DISPENSES': 'sum',
    'REASONDESCRIPTION': lambda x: ', '.join(x.dropna().unique()),
    'DAYS_SUPPLY': 'sum',
    'allergy_conflict': 'any'
}).reset_index()

# Optional rename
df_med_agg.rename(columns={
    'START': 'MED_START_DATE',
    'STOP': 'MED_STOP_DATE',
    'DESCRIPTION': 'MEDICATIONS',
    'REASONDESCRIPTION': 'MEDICATION_REASONS',
    'DAYS_SUPPLY': 'TOTAL_DAYS_SUPPLIED',
    'allergy_conflict': 'HAS_ALLERGY_CONFLICT'
}, inplace=True)

df_med_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PATIENT               105 non-null    object
#  1   MED_START_DATE        105 non-null    datetime64[ns, UTC]
#  2   MED_STOP_DATE         105 non-null    datetime64[ns, UTC]
#  3   MEDICATIONS           105 non-null    object
#  4   TOTALCOST             105 non-null    float64
#  5   DISPENSES             105 non-null    int64
#  6   MEDICATION_REASONS    105 non-null    object
#  7   TOTAL_DAYS_SUPPLIED   105 non-null    float64
#  8   HAS_ALLERGY_CONFLICT  105 non-null    bool
# dtypes: bool(1), datetime64[ns, UTC](2), float64(2), int64(1), object(3)
# memory usage: 6.8+ KB

# %%
df_C_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3876 entries, 0 to 3875
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START        3876 non-null   datetime64[ns]
#  1   STOP         2985 non-null   datetime64[ns]
#  2   PATIENT      3876 non-null   object
#  3   CODE         3876 non-null   int64
#  4   DESCRIPTION  3876 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 151.5+ KB

# %%
df_cond_agg = df_C_imp.groupby("PATIENT").agg({
    'START': 'min',
    'STOP': 'max',
    'DESCRIPTION': lambda x: ', '.join(x.dropna().unique()),
    'CODE': lambda x: ', '.join(str(code) for code in x.dropna().unique()),
}).reset_index()

# Optional: count of conditions
df_cond_agg['NUM_CONDITIONS'] = df_C_imp.groupby('PATIENT')['DESCRIPTION'].count().values

# Optional rename
df_cond_agg.rename(columns={
    'START': 'COND_FIRST_DATE',
    'STOP': 'COND_LAST_DATE',
    'DESCRIPTION': 'CONDITIONS',
    'CODE': 'CONDITION_CODES'
}, inplace=True)
df_cond_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PATIENT          106 non-null    object
#  1   COND_FIRST_DATE  106 non-null    datetime64[ns]
#  2   COND_LAST_DATE   106 non-null    datetime64[ns]
#  3   CONDITIONS       106 non-null    object
#  4   CONDITION_CODES  106 non-null    object
#  5   NUM_CONDITIONS   106 non-null    int64
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 5.1+ KB

# %%
df_merged = df_P_imp.merge(df_allergy_agg, how='left', left_on='Id', right_on='PATIENT')

# Merge with medication aggregates
df_merged = df_merged.merge(df_med_agg, how='left', left_on='Id', right_on='PATIENT', suffixes=('_allergy', '_med'))

# Merge with condition aggregates
df_merged = df_merged.merge(df_cond_agg, how='left', left_on='Id', right_on='PATIENT')

# Drop extra PATIENT columns to avoid confusion (since they are all the same after merging)
df_merged = df_merged.drop(columns=['PATIENT_allergy', 'PATIENT_med', 'PATIENT'])

# Optional: rename the main PATIENT ID column if needed
df_merged = df_merged.rename(columns={'Id': 'PATIENT_ID'})

# View the final merged dataframe
df_merged.head()
# Out:
#                              PATIENT_ID  BIRTHDATE   RACE    ETHNICITY GENDER  \
# 0  bad5a231-3709-952a-cf44-f8d6a52cc214 1961-11-15  white  nonhispanic      M
# 1  2bd4d47d-5e00-3b67-cdd7-03f4b811b711 1962-07-02  white  nonhispanic      F
# 2  74ad71cb-f64d-efce-02c9-ae3bc917c4a2 1994-07-24  white     hispanic      F
# 3  8d2a62f2-d630-6288-93ee-0fea3f859560 1960-06-08  white  nonhispanic      F
# 4  ba459391-501f-22f5-3446-7defd52e5fab 1962-09-02  white  nonhispanic      F
#
#                           BIRTHPLACE                           ADDRESS  \
# 0  North Pembroke  Massachusetts  US  544 Morissette Esplanade Unit 30
# 1   North Andover  Massachusetts  US         289 Powlowski Fort Apt 42
# 2  Portsmouth  Saint John Parish  DM                  242 Jerde Street
# 3         Danvers  Massachusetts  US                 691 Jacobson Quay
# 4      Winchester  Massachusetts  US                   1061 Mayer Road
#
# ...

# %%
df_merged.iloc[0]
# Out:
# PATIENT_ID                           bad5a231-3709-952a-cf44-f8d6a52cc214
# BIRTHDATE                                             1961-11-15 00:00:00
# RACE                                                                white
# ETHNICITY                                                     nonhispanic
# GENDER                                                                  M
# BIRTHPLACE                              North Pembroke  Massachusetts  US
# ADDRESS                                  544 Morissette Esplanade Unit 30
# CITY                                                              Tisbury
# STATE                                                       Massachusetts
# COUNTY                                                       Dukes County
# HEALTHCARE_EXPENSES                                             976441.28
# HEALTHCARE_COVERAGE                                             521994.74
# INCOME                                                             118047
# ...

# %%
# df_P_imp, df_A_imp, df_M_imp, df_C_imp, df_merged

# %%
from mongodb_crud import MongoCRUD
client = MongoCRUD(uri=uri,db_name=db_name)
client.create_mongo_collection("Patients_transformed")
client.create_mongo_collection("Allergies_transformed")
client.create_mongo_collection("Conditions_transformed")
client.create_mongo_collection("Medications_transformed")
client.create_mongo_collection("Merged_PACM")
# Out:
# ✅ Connected to MongoDB database: 'Medication_Management'
# Collection 'Patients_transformed' already exists.
# Collection 'Allergies_transformed' already exists.
# Collection 'Conditions_transformed' already exists.
# Collection 'Medications_transformed' already exists.
# Collection 'Merged_PACM' already exists.
# Collection(Database(MongoClient(host=['ac-anfs6gn-shard-00-00.71mo2sy.mongodb.net:27017', 'ac-anfs6gn-shard-00-02.71mo2sy.mongodb.net:27017', 'ac-anfs6gn-shard-00-01.71mo2sy.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Projects', authsource='admin', replicaset='atlas-xgg8e4-shard-0', tls=True), 'Medication_Management'), 'Merged_PACM')

# %%
# Replace NaT with None in all datetime columns
df_merged = df_merged.where(pd.notnull(df_merged), None)
datetime_cols = ['START', 'STOP']  # add more if needed
for col in datetime_cols:
    if col in df_merged.columns:
        df_merged[col] = df_merged[col].apply(lambda x: x if pd.notnull(x) else None)

# %%
import pandas as pd

def clean_datetime_for_mongo(df):
    for col in df.columns:
        if pd.api.types.is_datetime64_any_dtype(df[col]):
            # Convert timezone-aware to naive
            if df[col].dt.tz:
                df[col] = df[col].dt.tz_localize(None)
            # Replace NaT with None
            df[col] = df[col].apply(lambda x: x if pd.notnull(x) else None)
    return df

# %%
df_cleaned = clean_datetime_for_mongo(df_merged)
df_cleaned['BIRTHDATE'] = df_cleaned['BIRTHDATE'].astype(str)
df_cleaned['ALLERGY_START_DATE'] = df_cleaned['ALLERGY_START_DATE'].astype(str)
df_cleaned['MED_START_DATE'] = df_cleaned['MED_START_DATE'].astype(str)
df_cleaned['MED_STOP_DATE'] = df_cleaned['MED_STOP_DATE'].astype(str)
df_cleaned['COND_FIRST_DATE'] = df_cleaned['COND_FIRST_DATE'].astype(str)
df_cleaned['COND_LAST_DATE'] = df_cleaned['COND_LAST_DATE'].astype(str)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PATIENT_ID            106 non-null    object
#  1   BIRTHDATE             106 non-null    object
#  2   RACE                  106 non-null    object
#  3   ETHNICITY             106 non-null    object
#  4   GENDER                106 non-null    object
#  5   BIRTHPLACE            106 non-null    object
#  6   ADDRESS               106 non-null    object
#  7   CITY                  106 non-null    object
#  8   STATE                 106 non-null    object
#  9   COUNTY                106 non-null    object
#  10  HEALTHCARE_EXPENSES   106 non-null    float64
#  11  HEALTHCARE_COVERAGE   106 non-null    float64
#  12  INCOME                106 non-null    int64
#  13  BIRTHPLACE_COUNTRY    106 non-null    object
#  14  AGE                   106 non-null    int64
# ...

# %%
data = df_cleaned.to_dict(orient='records')
client.insert_documents("Merged_PACM",data)
# Out:
# Inserted 106 documents.
# [ObjectId('67f9e4cb1b65f2bd981ee3c2'),
#  ObjectId('67f9e4cb1b65f2bd981ee3c3'),
#  ObjectId('67f9e4cb1b65f2bd981ee3c4'),
#  ObjectId('67f9e4cb1b65f2bd981ee3c5'),
#  ObjectId('67f9e4cb1b65f2bd981ee3c6'),
#  ObjectId('67f9e4cb1b65f2bd981ee3c7'),
#  ObjectId('67f9e4cb1b65f2bd981ee3c8'),
#  ObjectId('67f9e4cb1b65f2bd981ee3c9'),
#  ObjectId('67f9e4cb1b65f2bd981ee3ca'),
#  ObjectId('67f9e4cb1b65f2bd981ee3cb'),
#  ObjectId('67f9e4cb1b65f2bd981ee3cc'),
#  ObjectId('67f9e4cb1b65f2bd981ee3cd'),
#  ObjectId('67f9e4cb1b65f2bd981ee3ce'),
#  ObjectId('67f9e4cb1b65f2bd981ee3cf'),
#  ObjectId('67f9e4cb1b65f2bd981ee3d0'),
#  ObjectId('67f9e4cb1b65f2bd981ee3d1'),
#  ObjectId('67f9e4cb1b65f2bd981ee3d2'),
#  ObjectId('67f9e4cb1b65f2bd981ee3d3'),
#  ObjectId('67f9e4cb1b65f2bd981ee3d4'),
#  ObjectId('67f9e4cb1b65f2bd981ee3d5'),
#  ObjectId('67f9e4cb1b65f2bd981ee3d6'),
#  ObjectId('67f9e4cb1b65f2bd981ee3d7'),
#  ObjectId('67f9e4cb1b65f2bd981ee3d8'),
# ...

# %%
# df_cleaned = clean_datetime_for_mongo(df_A_imp)
# print(df_A_imp.info())
# df_cleaned['START'] =   df_cleaned['START'].astype(str)
# data = df_cleaned.to_dict(orient='records')
# client.insert_documents("Allergies_transformed",data)

# %%
# df_cleaned = clean_datetime_for_mongo(df_C_imp)
# print(df_C_imp.info())
# df_cleaned['START'] =   df_cleaned['START'].astype(str)
# df_cleaned['STOP'] =   df_cleaned['STOP'].astype(str)

# data = df_cleaned.to_dict(orient='records')
# client.insert_documents("Conditions_transformed",data)

# %%
# df_cleaned = clean_datetime_for_mongo(df_P_imp)
# print(df_P_imp.info())
# df_cleaned['BIRTHDATE'] =   df_cleaned['BIRTHDATE'].astype(str)

# data = df_cleaned.to_dict(orient='records')
# client.insert_documents("Conditions_transformed",data)

# %%
# df_cleaned = clean_datetime_for_mongo(df_M_imp)
# print(df_M_imp.info())
# df_cleaned['START'] =   df_cleaned['START'].astype(str)
# df_cleaned['STOP'] =   df_cleaned['STOP'].astype(str)

# data = df_cleaned.to_dict(orient='records')
# client.insert_documents("Conditions_transformed",data)

# %% [markdown]
# # Get CSV

# %%
df_A_imp['START'] =   df_A_imp['START'].astype(str)
df_C_imp['START'] =   df_C_imp['START'].astype(str)
df_C_imp['STOP'] =   df_C_imp['STOP'].astype(str)
df_P_imp['BIRTHDATE'] =   df_P_imp['BIRTHDATE'].astype(str)
df_M_imp['START'] =   df_M_imp['START'].astype(str)
df_M_imp['STOP'] =   df_M_imp['STOP'].astype(str)

# %%
df_M_imp.to_excel("Medications_transformed.xlsx")
df_P_imp.to_excel("Patients_transformed.xlsx")
df_A_imp.to_excel("Allergies_transformed.xlsx")
df_C_imp.to_excel("Conditions_transformed.xlsx")

# %%
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 250 kB 8.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/mrunalpatil/Desktop/MrunalPatil/Study/Project /7th April 2025/Medication Management/medical_en/bin/python3 -m pip install --upgrade pip' command.
